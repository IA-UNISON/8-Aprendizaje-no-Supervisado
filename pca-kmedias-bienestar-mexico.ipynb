# %% [markdown]
# # Reducción de la dimensionalidad y exploración de datos
#
# Modificación de una libreta del [curso de José Dianes de `code mentor`](https://www.codementor.io/jadianes/data-science-python-pandas-r-dimensionality-reduction-du1081aka).
#
# ## Adquisición de los datos
#
# Los datos que vamos a analizar es la prevalencia de casos de tuberculosis en diferentes países desde 1990 al 2007. Estos datos provienen de la página [Gapminder website](http://www.gapminder.org/), en donde se encuentran muchos conjuntos de indicadores de diferentes paises y regiones del mundo. En su apartado [Data section](http://www.gapminder.org/data/) viene una lista de tablas que pueden ser descargadas como hojas de cálculo de *Google docs**.
#
# Para esta libreta vamos a usar el conjunto de datos [TB estimated prevalence (existing cases) per 100K](https://docs.google.com/spreadsheets/d/1X5Jp7Q8pTs3KLJ5JBWKhncVACGsg5v4xu6badNs4C7I/pub?gid=0), y lo vamos a descargar como un *csv*. Vamos a leer el archivo como un DataFrame de Pandas. Para quienes nunca han usado Pandas este es un modulo de python que se basa en numpy y que trata de replicar las facilidades de tratamiento de datos como tablas que ofrece el lenguaje de programación R. Si no tienes experiencia previa en Pandas se anexa en los documentos de la tarea una libreta de introducción al uso de Pandas que espero sea de utilidad.

# %% [markdown]
# Ahora vamos a leer el archivo como un `DataFrame` de `Pandas`. Para quienes nunca han usado `Pandas` este es un modulo de *python* que se basa en *numpy* y que trata de replicar las facilidades de tratamiento de datos como tablas que ofrece el lenguaje de programación *R*. Si no tienes experiencia previa en *Pandas* se anexa en los documentos de la tarea una libreta de introducción al uso de *Pandas* que espero sea de utilidad.

# %%
import numpy as np
import pandas as pd

url_csv = 'indicadores_bienestar_2014.csv'

tuberculosis_df = pd.read_csv(url_csv, index_col = 0, thousands  = ',')
tuberculosis_df.index.names = ['País']
tuberculosis_df.columns.names = ['Año']

# %% [markdown]
# Se especificó que `index_col` es 0 ya que los nombres de los países son las etiquetas de cada objeto. Dado que los datos numéricos vienen formateados, se le aviso al lector que los números tienen una coma para separar los miles. Por último se le dió un nombre a la columna de índices y otro nombre al renglon de etiquetas de los atributos. Veamos los 10 primeros datos:

# %%
tuberculosis_df.head()
# Out:
# Año                       Acceso a servicios de salud  \
# País
# Estados Unidos Mexicanos                         84.5
# Aguascalientes                                   87.9
# Baja California                                  80.6
# Baja California Sur                              84.9
# Campeche                                         89.3
#
# Año                       Hogares con acceso a banda ancha  \
# País
# Estados Unidos Mexicanos                             33.70
# Aguascalientes                                       37.92
# Baja California                                      51.46
# Baja California Sur                                  43.85
# Campeche                                             27.10
#
# Año                       Viviendas con acceso a servicios básicos  \
# País
# Estados Unidos Mexicanos                                      88.8
# Aguascalientes                                                98.0
# Baja California                                               94.7
# Baja California Sur                                           91.6
# Campeche                                                      89.8
#
# Año                       Participación cívica y política  \
# País
# Estados Unidos Mexicanos                              5.7
# Aguascalientes                                        8.4
# Baja California                                       4.1
# Baja California Sur                                   3.0
# Campeche                                             11.2
#
# Año                       Participación electoral  \
# País
# Estados Unidos Mexicanos                     47.7
# Aguascalientes                               37.2
# Baja California                              30.9
# Baja California Sur                          52.6
# Campeche                                     61.2
#
# Año                       Confianza en la aplicación de la ley  \
# País
# Estados Unidos Mexicanos                                  5.05
# Aguascalientes                                            5.60
# Baja California                                           4.05
# Baja California Sur                                       5.44
# Campeche                                                  8.12
#
# Año                       Percepción de ausencia de corrupción en el sistema judicial  \
# País
# Estados Unidos Mexicanos                                               28.3
# Aguascalientes                                                         34.7
# Baja California                                                        38.1
# Baja California Sur                                                    37.2
# Campeche                                                               32.7
#
# Año                       Percepción de confianza en los jueces  \
# País
# Estados Unidos Mexicanos                                   53.7
# Aguascalientes                                             63.2
# Baja California                                            62.7
# Baja California Sur                                        66.9
# Campeche                                                   63.5
#
# Año                       Calidad de la red social de soporte  \
# País
# Estados Unidos Mexicanos                                 77.3
# Aguascalientes                                           78.1
# Baja California                                          84.7
# Baja California Sur                                      85.0
# Campeche                                                 73.5
#
# Año                       Esperanza de vida al nacer  \
# País
# Estados Unidos Mexicanos                        75.0
# Aguascalientes                                  75.9
# Baja California                                 74.2
# Baja California Sur                             76.2
# Campeche                                        75.4
#
# Año                                                   ...                               \
# País                                                  ...
# Estados Unidos Mexicanos                              ...
# Aguascalientes                                        ...
# Baja California                                       ...
# Baja California Sur                                   ...
# Campeche                                              ...
#
# Año                       Porcentaje de la población en situación de pobreza  \
# País
# Estados Unidos Mexicanos                                               43.6
# Aguascalientes                                                         28.2
# Baja California                                                        22.2
# Baja California Sur                                                    22.1
# Campeche                                                               43.8
#
# Año                       Porcentaje de la población en situación de pobreza extrema  \
# País
# Estados Unidos Mexicanos                                                7.6
# Aguascalientes                                                          2.3
# Baja California                                                         1.1
# Baja California Sur                                                     1.6
# Campeche                                                                6.7
#
# Año                       Tasa de condiciones críticas de ocupación  \
# País
# Estados Unidos Mexicanos                                       13.8
# Aguascalientes                                                 10.5
# Baja California                                                 7.0
# Baja California Sur                                             6.3
# Campeche                                                       17.7
#
# Año                       Tasa de informalidad laboral  Tasa de desocupación  \
# País
# Estados Unidos Mexicanos                         57.29                   3.9
# Aguascalientes                                   43.91                   4.0
# Baja California                                  39.91                   2.6
# Baja California Sur                              39.05                   4.6
# Campeche                                         62.08                   3.7
#
# Año                       Tasa de participación económica  \
# País
# Estados Unidos Mexicanos                             59.7
# Aguascalientes                                       60.0
# Baja California                                      61.4
# Baja California Sur                                  66.1
# Campeche                                             61.0
#
# Año                       Contaminación del aire  Disposición de residuos  \
# País
# Estados Unidos Mexicanos                    11.5                     67.5
# Aguascalientes                               9.1                    100.0
# Baja California                              6.8                     95.7
# Baja California Sur                          6.1                     80.5
# Campeche                                     4.2                     44.9
#
# Año                       Habitaciones por persona  \
# País
# Estados Unidos Mexicanos                       1.0
# Aguascalientes                                 1.0
# Baja California                                1.1
# Baja California Sur                            1.0
# Campeche                                       0.8
#
# Año                       Porcentaje de viviendas con techos de materiales resistentes
# País
# Estados Unidos Mexicanos                                               71.6
# Aguascalientes                                                         94.9
# Baja California                                                        49.5
# Baja California Sur                                                    74.8
# Campeche                                                               52.7
#
# [5 rows x 37 columns]

# %% [markdown]
# Y vamos a ver un resumen de la informaci´n que tenemos en el `DataFrame`:

# %%
tuberculosis_df.describe()
# Out:
# Año    Acceso a servicios de salud  Hogares con acceso a banda ancha  \
# count                    33.000000                         33.000000
# mean                     85.360606                         33.524848
# std                       2.909139                         10.908865
# min                      77.200000                          9.470000
# 25%                      84.500000                         25.810000
# 50%                      85.600000                         33.350000
# 75%                      87.200000                         41.390000
# max                      90.900000                         55.100000
#
# Año    Viviendas con acceso a servicios básicos  \
# count                                 33.000000
# mean                                  89.027273
# std                                    8.661310
# min                                   60.200000
# 25%                                   86.800000
# 50%                                   91.600000
# 75%                                   94.700000
# max                                   98.500000
#
# Año    Participación cívica y política  Participación electoral  \
# count                        33.000000                33.000000
# mean                          7.054545                48.139394
# std                           2.965225                 9.092852
# min                           1.700000                30.900000
# 25%                           4.100000                41.700000
# 50%                           7.000000                46.000000
# 75%                           9.300000                55.300000
# max                          13.000000                70.900000
#
# Año    Confianza en la aplicación de la ley  \
# count                             33.000000
# mean                               6.009091
# std                                2.646946
# min                                0.910000
# 25%                                4.360000
# 50%                                5.610000
# 75%                                7.240000
# max                               13.960000
#
# Año    Percepción de ausencia de corrupción en el sistema judicial  \
# count                                          33.000000
# mean                                           31.787879
# std                                             6.857922
# min                                            18.300000
# 25%                                            27.900000
# 50%                                            31.100000
# 75%                                            37.200000
# max                                            45.000000
#
# Año    Percepción de confianza en los jueces  \
# count                              33.000000
# mean                               59.093939
# std                                 7.052789
# min                                33.300000
# 25%                                56.300000
# 50%                                60.100000
# 75%                                63.600000
# max                                68.400000
#
# Año    Calidad de la red social de soporte  Esperanza de vida al nacer  \
# count                            33.000000                   33.000000
# mean                             78.618182                   75.215152
# std                               3.790486                    0.944101
# min                              69.800000                   73.000000
# 25%                              76.000000                   74.900000
# 50%                              78.900000                   75.500000
# 75%                              81.600000                   75.900000
# max                              85.000000                   76.700000
#
# Año                                ...                               \
# count                              ...
# mean                               ...
# std                                ...
# min                                ...
# 25%                                ...
# 50%                                ...
# 75%                                ...
# max                                ...
#
# Año    Porcentaje de la población en situación de pobreza  \
# count                                          33.000000
# mean                                           41.430303
# std                                            14.999010
# min                                            14.200000
# 25%                                            30.600000
# 50%                                            41.900000
# 75%                                            50.600000
# max                                            77.100000
#
# Año    Porcentaje de la población en situación de pobreza extrema  \
# count                                          33.000000
# mean                                            6.942424
# std                                             7.034959
# min                                             0.600000
# 25%                                             2.600000
# 50%                                             4.400000
# 75%                                             7.900000
# max                                            28.100000
#
# Año    Tasa de condiciones críticas de ocupación  \
# count                                  33.000000
# mean                                   13.375758
# std                                     6.055319
# min                                     4.800000
# 25%                                     9.400000
# 50%                                    12.500000
# 75%                                    16.800000
# max                                    33.400000
#
# Año    Tasa de informalidad laboral  Tasa de desocupación  \
# count                     33.000000             33.000000
# mean                      57.137576              3.727273
# std                       13.472917              1.117831
# min                       35.430000              2.000000
# 25%                       47.700000              3.000000
# 50%                       56.890000              3.700000
# 75%                       67.330000              4.400000
# max                       82.020000              7.400000
#
# Año    Tasa de participación económica  Contaminación del aire  \
# count                        33.000000               33.000000
# mean                         60.381818               10.027273
# std                           3.344160                4.638782
# min                          52.300000                3.400000
# 25%                          58.400000                6.800000
# 50%                          60.400000                9.100000
# 75%                          61.800000               12.200000
# max                          67.300000               26.200000
#
# Año    Disposición de residuos  Habitaciones por persona  \
# count                33.000000                 33.000000
# mean                 62.512121                  0.957576
# std                  24.068532                  0.111888
# min                   1.500000                  0.700000
# 25%                  44.900000                  0.900000
# 50%                  67.500000                  1.000000
# 75%                  80.500000                  1.000000
# max                 100.000000                  1.200000
#
# Año    Porcentaje de viviendas con techos de materiales resistentes
# count                                          33.000000
# mean                                           70.972727
# std                                            16.715043
# min                                            29.800000
# 25%                                            66.700000
# 50%                                            74.800000
# 75%                                            82.700000
# max                                            94.900000
#
# [8 rows x 37 columns]

# %% [markdown]
# Como podemos ver, son 207 paises y para nuestro análisis (o al menos como queremos hacer más adelante el análisis de los estados de México) son demasiados, por lo que vamos a seleccionar 30 al azar (y cada vez será diferente para que esto se ponga entretenido).

# %%
red_df = tuberculosis_df.sample(30)

red_df
# Out:
# Año                              Acceso a servicios de salud  \
# País
# Campeche                                                89.3
# Zacatecas                                               88.5
# Nuevo León                                              86.7
# Michoacán de Ocampo                                     77.2
# Baja California Sur                                     84.9
# Chiapas                                                 85.0
# Durango                                                 85.9
# Ciudad de México                                        80.1
# Aguascalientes                                          87.9
# Sinaloa                                                 87.8
# Tabasco                                                 86.6
# Coahuila de Zaragoza                                    87.2
# Puebla                                                  82.6
# Hidalgo                                                 85.6
# Quintana Roo                                            82.4
# San Luis Potosí                                         90.9
# Guanajuato                                              86.6
# Oaxaca                                                  84.1
# Morelos                                                 85.0
# Yucatán                                                 85.6
# Colima                                                  88.1
# Guerrero                                                86.7
# Nayarit                                                 85.0
# Jalisco                                                 82.4
# Veracruz de Ignacio de la Llave                         80.6
# Estados Unidos Mexicanos                                84.5
# Sonora                                                  85.3
# Querétaro                                               86.8
# México                                                  84.5
# Tamaulipas                                              87.2
#
# Año                              Hogares con acceso a banda ancha  \
# País
# Campeche                                                    27.10
# Zacatecas                                                   25.81
# Nuevo León                                                  55.10
# Michoacán de Ocampo                                         23.68
# Baja California Sur                                         43.85
# Chiapas                                                      9.47
# Durango                                                     30.32
# Ciudad de México                                            53.02
# Aguascalientes                                              37.92
# Sinaloa                                                     38.15
# Tabasco                                                     28.65
# Coahuila de Zaragoza                                        34.56
# Puebla                                                      23.84
# Hidalgo                                                     25.62
# Quintana Roo                                                46.71
# San Luis Potosí                                             27.18
# Guanajuato                                                  27.55
# Oaxaca                                                      14.00
# Morelos                                                     38.44
# Yucatán                                                     29.51
# Colima                                                      45.16
# Guerrero                                                    20.66
# Nayarit                                                     35.85
# Jalisco                                                     41.39
# Veracruz de Ignacio de la Llave                             21.18
# Estados Unidos Mexicanos                                    33.70
# Sonora                                                      45.94
# Querétaro                                                   32.30
# México                                                      33.35
# Tamaulipas                                                  37.21
#
# Año                              Viviendas con acceso a servicios básicos  \
# País
# Campeche                                                             89.8
# Zacatecas                                                            90.8
# Nuevo León                                                           97.6
# Michoacán de Ocampo                                                  85.4
# Baja California Sur                                                  91.6
# Chiapas                                                              77.8
# Durango                                                              92.8
# Ciudad de México                                                     98.5
# Aguascalientes                                                       98.0
# Sinaloa                                                              93.2
# Tabasco                                                              74.4
# Coahuila de Zaragoza                                                 96.0
# Puebla                                                               84.2
# Hidalgo                                                              86.8
# Quintana Roo                                                         93.4
# San Luis Potosí                                                      82.8
# Guanajuato                                                           90.7
# Oaxaca                                                               60.2
# Morelos                                                              90.0
# Yucatán                                                              89.3
# Colima                                                               98.3
# Guerrero                                                             70.3
# Nayarit                                                              90.1
# Jalisco                                                              97.1
# Veracruz de Ignacio de la Llave                                      76.8
# Estados Unidos Mexicanos                                             88.8
# Sonora                                                               91.7
# Querétaro                                                            92.9
# México                                                               92.1
# Tamaulipas                                                           92.4
#
# Año                              Participación cívica y política  \
# País
# Campeche                                                    11.2
# Zacatecas                                                    8.2
# Nuevo León                                                   4.1
# Michoacán de Ocampo                                          7.9
# Baja California Sur                                          3.0
# Chiapas                                                     10.8
# Durango                                                      5.5
# Ciudad de México                                             3.3
# Aguascalientes                                               8.4
# Sinaloa                                                      6.2
# Tabasco                                                      9.6
# Coahuila de Zaragoza                                         6.5
# Puebla                                                       3.5
# Hidalgo                                                      9.1
# Quintana Roo                                                 9.0
# San Luis Potosí                                              7.0
# Guanajuato                                                   1.7
# Oaxaca                                                       8.8
# Morelos                                                      8.5
# Yucatán                                                      9.3
# Colima                                                      13.0
# Guerrero                                                    12.0
# Nayarit                                                      9.7
# Jalisco                                                      3.5
# Veracruz de Ignacio de la Llave                              5.0
# Estados Unidos Mexicanos                                     5.7
# Sonora                                                       9.8
# Querétaro                                                    5.6
# México                                                       3.4
# Tamaulipas                                                   6.8
#
# Año                              Participación electoral  \
# País
# Campeche                                            61.2
# Zacatecas                                           45.5
# Nuevo León                                          58.7
# Michoacán de Ocampo                                 54.9
# Baja California Sur                                 52.6
# Chiapas                                             46.3
# Durango                                             41.6
# Ciudad de México                                    44.2
# Aguascalientes                                      37.2
# Sinaloa                                             38.5
# Tabasco                                             57.0
# Coahuila de Zaragoza                                45.0
# Puebla                                              41.7
# Hidalgo                                             45.4
# Quintana Roo                                        39.9
# San Luis Potosí                                     57.4
# Guanajuato                                          45.9
# Oaxaca                                              36.4
# Morelos                                             55.3
# Yucatán                                             70.9
# Colima                                              60.2
# Guerrero                                            56.4
# Nayarit                                             41.8
# Jalisco                                             52.9
# Veracruz de Ignacio de la Llave                     46.0
# Estados Unidos Mexicanos                            47.7
# Sonora                                              52.0
# Querétaro                                           57.5
# México                                              50.5
# Tamaulipas                                          45.1
#
# Año                              Confianza en la aplicación de la ley  \
# País
# Campeche                                                         8.12
# Zacatecas                                                        6.41
# Nuevo León                                                       6.87
# Michoacán de Ocampo                                              5.10
# Baja California Sur                                              5.44
# Chiapas                                                         13.96
# Durango                                                          6.75
# Ciudad de México                                                 0.91
# Aguascalientes                                                   5.60
# Sinaloa                                                          8.21
# Tabasco                                                          4.48
# Coahuila de Zaragoza                                             7.62
# Puebla                                                           3.33
# Hidalgo                                                          3.98
# Quintana Roo                                                     4.91
# San Luis Potosí                                                  5.61
# Guanajuato                                                       3.29
# Oaxaca                                                           7.33
# Morelos                                                          3.04
# Yucatán                                                         11.20
# Colima                                                           8.76
# Guerrero                                                         5.78
# Nayarit                                                         10.72
# Jalisco                                                          5.92
# Veracruz de Ignacio de la Llave                                  4.20
# Estados Unidos Mexicanos                                         5.05
# Sonora                                                           7.24
# Querétaro                                                        6.18
# México                                                           1.92
# Tamaulipas                                                       6.87
#
# Año                              Percepción de ausencia de corrupción en el sistema judicial  \
# País
# Campeche                                                                      32.7
# Zacatecas                                                                     45.0
# Nuevo León                                                                    43.9
# Michoacán de Ocampo                                                           31.0
# Baja California Sur                                                           37.2
# Chiapas                                                                       32.8
# Durango                                                                       39.7
# Ciudad de México                                                              18.3
# Aguascalientes                                                                34.7
# Sinaloa                                                                       28.8
# Tabasco                                                                       29.7
# Coahuila de Zaragoza                                                          34.3
# Puebla                                                                        24.5
# Hidalgo                                                                       30.5
# Quintana Roo                                                                  23.8
# San Luis Potosí                                                               38.1
# Guanajuato                                                                    36.9
# Oaxaca                                                                        23.7
# Morelos                                                                       19.1
# Yucatán                                                                       31.8
# Colima                                                                        37.7
# Guerrero                                                                      27.1
# Nayarit                                                                       39.3
# Jalisco                                                                       27.9
# Veracruz de Ignacio de la Llave                                               29.3
# Estados Unidos Mexicanos                                                      28.3
# Sonora                                                                        32.9
# Querétaro                                                                     29.4
# México                                                                        22.7
# Tamaulipas                                                                    43.8
#
# Año                              Percepción de confianza en los jueces  \
# País
# Campeche                                                          63.5
# Zacatecas                                                         66.8
# Nuevo León                                                        65.9
# Michoacán de Ocampo                                               60.1
# Baja California Sur                                               66.9
# Chiapas                                                           63.5
# Durango                                                           62.1
# Ciudad de México                                                  33.3
# Aguascalientes                                                    63.2
# Sinaloa                                                           63.6
# Tabasco                                                           56.3
# Coahuila de Zaragoza                                              59.2
# Puebla                                                            53.9
# Hidalgo                                                           64.1
# Quintana Roo                                                      56.6
# San Luis Potosí                                                   65.5
# Guanajuato                                                        61.3
# Oaxaca                                                            59.4
# Morelos                                                           53.5
# Yucatán                                                           63.9
# Colima                                                            61.6
# Guerrero                                                          57.5
# Nayarit                                                           68.4
# Jalisco                                                           56.3
# Veracruz de Ignacio de la Llave                                   46.9
# Estados Unidos Mexicanos                                          53.7
# Sonora                                                            58.2
# Querétaro                                                         54.9
# México                                                            46.0
# Tamaulipas                                                        63.9
#
# Año                              Calidad de la red social de soporte  \
# País
# Campeche                                                        73.5
# Zacatecas                                                       80.5
# Nuevo León                                                      83.3
# Michoacán de Ocampo                                             73.3
# Baja California Sur                                             85.0
# Chiapas                                                         77.8
# Durango                                                         78.5
# Ciudad de México                                                69.8
# Aguascalientes                                                  78.1
# Sinaloa                                                         81.6
# Tabasco                                                         82.6
# Coahuila de Zaragoza                                            81.4
# Puebla                                                          74.1
# Hidalgo                                                         72.1
# Quintana Roo                                                    81.0
# San Luis Potosí                                                 76.0
# Guanajuato                                                      75.2
# Oaxaca                                                          74.9
# Morelos                                                         77.6
# Yucatán                                                         79.2
# Colima                                                          79.6
# Guerrero                                                        77.0
# Nayarit                                                         80.1
# Jalisco                                                         78.9
# Veracruz de Ignacio de la Llave                                 77.2
# Estados Unidos Mexicanos                                        77.3
# Sonora                                                          83.9
# Querétaro                                                       81.7
# México                                                          74.5
# Tamaulipas                                                      82.3
#
# Año                              Esperanza de vida al nacer  \
# País
# Campeche                                               75.4
# Zacatecas                                              75.5
# Nuevo León                                             76.7
# Michoacán de Ocampo                                    74.9
# Baja California Sur                                    76.2
# Chiapas                                                73.0
# Durango                                                76.0
# Ciudad de México                                       76.2
# Aguascalientes                                         75.9
# Sinaloa                                                75.8
# Tabasco                                                74.9
# Coahuila de Zaragoza                                   76.0
# Puebla                                                 75.0
# Hidalgo                                                74.6
# Quintana Roo                                           75.8
# San Luis Potosí                                        74.9
# Guanajuato                                             75.6
# Oaxaca                                                 73.2
# Morelos                                                75.9
# Yucatán                                                75.6
# Colima                                                 76.1
# Guerrero                                               73.1
# Nayarit                                                75.4
# Jalisco                                                75.7
# Veracruz de Ignacio de la Llave                        74.2
# Estados Unidos Mexicanos                               75.0
# Sonora                                                 75.5
# Querétaro                                              75.5
# México                                                 75.4
# Tamaulipas                                             76.0
#
# Año                                                          ...                               \
# País                                                         ...
# Campeche                                                     ...
# Zacatecas                                                    ...
# Nuevo León                                                   ...
# Michoacán de Ocampo                                          ...
# Baja California Sur                                          ...
# Chiapas                                                      ...
# Durango                                                      ...
# Ciudad de México                                             ...
# Aguascalientes                                               ...
# Sinaloa                                                      ...
# Tabasco                                                      ...
# Coahuila de Zaragoza                                         ...
# Puebla                                                       ...
# Hidalgo                                                      ...
# Quintana Roo                                                 ...
# San Luis Potosí                                              ...
# Guanajuato                                                   ...
# Oaxaca                                                       ...
# Morelos                                                      ...
# Yucatán                                                      ...
# Colima                                                       ...
# Guerrero                                                     ...
# Nayarit                                                      ...
# Jalisco                                                      ...
# Veracruz de Ignacio de la Llave                              ...
# Estados Unidos Mexicanos                                     ...
# Sonora                                                       ...
# Querétaro                                                    ...
# México                                                       ...
# Tamaulipas                                                   ...
#
# Año                              Porcentaje de la población en situación de pobreza  \
# País
# Campeche                                                                      43.8
# Zacatecas                                                                     49.0
# Nuevo León                                                                    14.2
# Michoacán de Ocampo                                                           55.3
# Baja California Sur                                                           22.1
# Chiapas                                                                       77.1
# Durango                                                                       36.0
# Ciudad de México                                                              27.6
# Aguascalientes                                                                28.2
# Sinaloa                                                                       30.8
# Tabasco                                                                       50.9
# Coahuila de Zaragoza                                                          24.8
# Puebla                                                                        59.4
# Hidalgo                                                                       50.6
# Quintana Roo                                                                  28.8
# San Luis Potosí                                                               45.5
# Guanajuato                                                                    42.4
# Oaxaca                                                                        70.4
# Morelos                                                                       49.5
# Yucatán                                                                       41.9
# Colima                                                                        33.6
# Guerrero                                                                      64.4
# Nayarit                                                                       37.5
# Jalisco                                                                       31.8
# Veracruz de Ignacio de la Llave                                               62.2
# Estados Unidos Mexicanos                                                      43.6
# Sonora                                                                        27.9
# Querétaro                                                                     31.1
# México                                                                        47.9
# Tamaulipas                                                                    32.2
#
# Año                              Porcentaje de la población en situación de pobreza extrema  \
# País
# Campeche                                                                       6.7
# Zacatecas                                                                      3.5
# Nuevo León                                                                     0.6
# Michoacán de Ocampo                                                            9.4
# Baja California Sur                                                            1.6
# Chiapas                                                                       28.1
# Durango                                                                        2.8
# Ciudad de México                                                               1.8
# Aguascalientes                                                                 2.3
# Sinaloa                                                                        2.9
# Tabasco                                                                       11.8
# Coahuila de Zaragoza                                                           1.7
# Puebla                                                                         9.0
# Hidalgo                                                                        8.0
# Quintana Roo                                                                   4.2
# San Luis Potosí                                                                7.7
# Guanajuato                                                                     4.4
# Oaxaca                                                                        26.9
# Morelos                                                                        5.9
# Yucatán                                                                        6.1
# Colima                                                                         2.6
# Guerrero                                                                      23.0
# Nayarit                                                                        7.9
# Jalisco                                                                        1.8
# Veracruz de Ignacio de la Llave                                               16.4
# Estados Unidos Mexicanos                                                       7.6
# Sonora                                                                         2.5
# Querétaro                                                                      2.9
# México                                                                         6.1
# Tamaulipas                                                                     2.9
#
# Año                              Tasa de condiciones críticas de ocupación  \
# País
# Campeche                                                              17.7
# Zacatecas                                                             14.2
# Nuevo León                                                             4.8
# Michoacán de Ocampo                                                   12.5
# Baja California Sur                                                    6.3
# Chiapas                                                               33.4
# Durango                                                               14.3
# Ciudad de México                                                      11.8
# Aguascalientes                                                        10.5
# Sinaloa                                                                8.2
# Tabasco                                                               14.6
# Coahuila de Zaragoza                                                   9.5
# Puebla                                                                20.3
# Hidalgo                                                               21.4
# Quintana Roo                                                          10.4
# San Luis Potosí                                                       13.7
# Guanajuato                                                            16.5
# Oaxaca                                                                21.0
# Morelos                                                               10.8
# Yucatán                                                               17.3
# Colima                                                                 9.4
# Guerrero                                                              18.1
# Nayarit                                                               12.2
# Jalisco                                                                7.1
# Veracruz de Ignacio de la Llave                                       16.8
# Estados Unidos Mexicanos                                              13.8
# Sonora                                                                 7.5
# Querétaro                                                              6.7
# México                                                                15.5
# Tamaulipas                                                            10.6
#
# Año                              Tasa de informalidad laboral  \
# País
# Campeche                                                62.08
# Zacatecas                                               63.25
# Nuevo León                                              36.32
# Michoacán de Ocampo                                     72.07
# Baja California Sur                                     39.05
# Chiapas                                                 79.35
# Durango                                                 53.60
# Ciudad de México                                        47.83
# Aguascalientes                                          43.91
# Sinaloa                                                 51.41
# Tabasco                                                 65.25
# Coahuila de Zaragoza                                    37.44
# Puebla                                                  73.47
# Hidalgo                                                 72.77
# Quintana Roo                                            47.70
# San Luis Potosí                                         58.58
# Guanajuato                                              56.15
# Oaxaca                                                  82.02
# Morelos                                                 67.33
# Yucatán                                                 62.74
# Colima                                                  53.06
# Guerrero                                                79.04
# Nayarit                                                 62.86
# Jalisco                                                 49.81
# Veracruz de Ignacio de la Llave                         69.39
# Estados Unidos Mexicanos                                57.29
# Sonora                                                  44.78
# Querétaro                                               43.92
# México                                                  56.89
# Tamaulipas                                              48.14
#
# Año                              Tasa de desocupación  \
# País
# Campeche                                          3.7
# Zacatecas                                         2.8
# Nuevo León                                        4.3
# Michoacán de Ocampo                               2.7
# Baja California Sur                               4.6
# Chiapas                                           3.1
# Durango                                           4.5
# Ciudad de México                                  5.0
# Aguascalientes                                    4.0
# Sinaloa                                           3.7
# Tabasco                                           7.4
# Coahuila de Zaragoza                              4.4
# Puebla                                            3.0
# Hidalgo                                           3.1
# Quintana Roo                                      3.2
# San Luis Potosí                                   2.4
# Guanajuato                                        4.0
# Oaxaca                                            2.0
# Morelos                                           2.6
# Yucatán                                           2.0
# Colima                                            4.1
# Guerrero                                          2.0
# Nayarit                                           4.0
# Jalisco                                           3.7
# Veracruz de Ignacio de la Llave                   3.6
# Estados Unidos Mexicanos                          3.9
# Sonora                                            5.0
# Querétaro                                         4.5
# México                                            5.2
# Tamaulipas                                        4.6
#
# Año                              Tasa de participación económica  \
# País
# Campeche                                                    61.0
# Zacatecas                                                   56.0
# Nuevo León                                                  61.3
# Michoacán de Ocampo                                         60.0
# Baja California Sur                                         66.1
# Chiapas                                                     55.7
# Durango                                                     61.5
# Ciudad de México                                            61.5
# Aguascalientes                                              60.0
# Sinaloa                                                     61.1
# Tabasco                                                     58.4
# Coahuila de Zaragoza                                        61.9
# Puebla                                                      60.4
# Hidalgo                                                     58.0
# Quintana Roo                                                67.3
# San Luis Potosí                                             58.6
# Guanajuato                                                  60.3
# Oaxaca                                                      58.4
# Morelos                                                     56.3
# Yucatán                                                     64.0
# Colima                                                      66.9
# Guerrero                                                    58.3
# Nayarit                                                     64.1
# Jalisco                                                     61.8
# Veracruz de Ignacio de la Llave                             52.3
# Estados Unidos Mexicanos                                    59.7
# Sonora                                                      63.3
# Querétaro                                                   54.1
# México                                                      59.1
# Tamaulipas                                                  61.6
#
# Año                              Contaminación del aire  \
# País
# Campeche                                            4.2
# Zacatecas                                           7.2
# Nuevo León                                          9.4
# Michoacán de Ocampo                                13.9
# Baja California Sur                                 6.1
# Chiapas                                             6.9
# Durango                                             8.1
# Ciudad de México                                   15.1
# Aguascalientes                                      9.1
# Sinaloa                                             7.4
# Tabasco                                             8.2
# Coahuila de Zaragoza                                8.4
# Puebla                                             13.7
# Hidalgo                                            13.7
# Quintana Roo                                        3.7
# San Luis Potosí                                    10.4
# Guanajuato                                         16.1
# Oaxaca                                              8.8
# Morelos                                            26.2
# Yucatán                                             3.4
# Colima                                              9.4
# Guerrero                                           11.0
# Nayarit                                             6.1
# Jalisco                                            12.2
# Veracruz de Ignacio de la Llave                    11.3
# Estados Unidos Mexicanos                           11.5
# Sonora                                              6.1
# Querétaro                                          16.3
# México                                             15.7
# Tamaulipas                                          6.6
#
# Año                              Disposición de residuos  \
# País
# Campeche                                            44.9
# Zacatecas                                           53.4
# Nuevo León                                          97.6
# Michoacán de Ocampo                                 40.1
# Baja California Sur                                 80.5
# Chiapas                                             29.0
# Durango                                             78.6
# Ciudad de México                                   100.0
# Aguascalientes                                     100.0
# Sinaloa                                             80.2
# Tabasco                                             34.4
# Coahuila de Zaragoza                                72.0
# Puebla                                              80.5
# Hidalgo                                             27.9
# Quintana Roo                                        74.4
# San Luis Potosí                                     57.8
# Guanajuato                                          70.8
# Oaxaca                                               1.5
# Morelos                                             29.2
# Yucatán                                             57.8
# Colima                                              51.1
# Guerrero                                            43.5
# Nayarit                                             56.3
# Jalisco                                             81.0
# Veracruz de Ignacio de la Llave                     37.1
# Estados Unidos Mexicanos                            67.5
# Sonora                                              48.0
# Querétaro                                           73.7
# México                                              57.5
# Tamaulipas                                          71.0
#
# Año                              Habitaciones por persona  \
# País
# Campeche                                              0.8
# Zacatecas                                             1.0
# Nuevo León                                            1.1
# Michoacán de Ocampo                                   0.9
# Baja California Sur                                   1.0
# Chiapas                                               0.7
# Durango                                               1.0
# Ciudad de México                                      1.2
# Aguascalientes                                        1.0
# Sinaloa                                               1.0
# Tabasco                                               0.9
# Coahuila de Zaragoza                                  1.1
# Puebla                                                0.9
# Hidalgo                                               0.9
# Quintana Roo                                          0.8
# San Luis Potosí                                       1.0
# Guanajuato                                            0.9
# Oaxaca                                                0.8
# Morelos                                               1.0
# Yucatán                                               0.9
# Colima                                                1.0
# Guerrero                                              0.7
# Nayarit                                               1.0
# Jalisco                                               1.0
# Veracruz de Ignacio de la Llave                       0.9
# Estados Unidos Mexicanos                              1.0
# Sonora                                                1.0
# Querétaro                                             1.0
# México                                                1.0
# Tamaulipas                                            1.0
#
# Año                              Porcentaje de viviendas con techos de materiales resistentes
# País
# Campeche                                                                      52.7
# Zacatecas                                                                     73.0
# Nuevo León                                                                    87.9
# Michoacán de Ocampo                                                           66.7
# Baja California Sur                                                           74.8
# Chiapas                                                                       29.8
# Durango                                                                       68.0
# Ciudad de México                                                              90.6
# Aguascalientes                                                                94.9
# Sinaloa                                                                       90.1
# Tabasco                                                                       38.5
# Coahuila de Zaragoza                                                          77.8
# Puebla                                                                        70.2
# Hidalgo                                                                       75.4
# Quintana Roo                                                                  82.4
# San Luis Potosí                                                               73.7
# Guanajuato                                                                    81.3
# Oaxaca                                                                        43.2
# Morelos                                                                       77.9
# Yucatán                                                                       86.8
# Colima                                                                        70.8
# Guerrero                                                                      47.0
# Nayarit                                                                       75.9
# Jalisco                                                                       88.3
# Veracruz de Ignacio de la Llave                                               47.2
# Estados Unidos Mexicanos                                                      71.6
# Sonora                                                                        67.2
# Querétaro                                                                     83.6
# México                                                                        82.7
# Tamaulipas                                                                    77.2
#
# [30 rows x 37 columns]

# %% [markdown]
# ## Reducción de la dimensionalidad con PCA
#
# Como en este caso lo que nos interesa es poder hacer una exploración de los datos, vamos a usar el análisis en componentes principales como una herramienta para obtener la mejor foto posible de los datos que nos interesan. Por esta razón, solo vamos a utilizar las dos primeras componentes principales.
#
# Para hacer los componentes principales, no los vamos a programar, si no que vamos a utilizar una biblioteca superpoderosa para aprendizaje máquina `Sklearn`. Si bien estas bibliotecas nos facilitan la vida, hay que tener cuidado de entender la documentación y saber que hace cada algoritmo, si no estaríamos como *el burro que toco la flauta*.
#
# Por ejemplo, para hacer el análisis en componentes principales, simplemente tenemos que hacer:

# %%
from sklearn.decomposition import PCA

pca = PCA(n_components=2)
pca.fit(red_df)
# Out:
# PCA(copy=True, iterated_power='auto', n_components=2, random_state=None,
#   svd_solver='auto', tol=0.0, whiten=False)

# %% [markdown]
# Y con el objeto `pca`previamente entrenado, podemos transformar nuestros datos en dos dimensiones como

# %%
red_pca = pca.transform(red_df)

# %% [markdown]
# Tambien hubieramos podido llamar simplemente `fit_transform` para hacer ambos pasos en uno solo. Ahora vamos a transformar el `ndarray` que obtuvimos en un `DataFrame` de *Pandas* para mantener el formato.

# %%
red_pca_df = pd.DataFrame(red_pca)
red_pca_df.index = red_df.index
red_pca_df.columns = ['CP_1','CP_2']
red_pca_df.head()
# Out:
#                             CP_1         CP_2
# País
# Campeche            -5320.394671  1295.985252
# Zacatecas           -7379.070064  -620.455115
# Nuevo León            642.659297  3035.069399
# Michoacán de Ocampo -5259.668672 -1005.627186
# Baja California Sur  -504.828963  1684.503983

# %% [markdown]
# La varianza de los datos que explican los dos primeros componentes principales es:

# %%
print(pca.explained_variance_ratio_)
# Out:
# [ 0.95462134  0.04534711]

# %% [markdown]
# #### Pregunta para contestar:
# ¿Cuanta varianza explica la primer componente principal?
#     0.95462134
# ¿Y la segunda?
#     0.04534711
# ¿Es una mucho mayor que la otra?
#     Si
# ¿Que puede significar eso?
#     Los datos de la primera estan muchisimo mas dispersos que la otra.
# ¿Se explica el 98 % de la varianza con ambas o no?
#     si

# %% [markdown]
# Ya estamos listos para imprimir los resultados y vamos a usar las facilidades de graficación que provée *Pandas*. Si quieres saber más, consulta [aquí](http://pandas.pydata.org/pandas-docs/version/0.15.0/visualization.html). Y para que se vea *fancy* vamos a agregar el nombre del país a cada uno de los puntos de la gráfica.

# %%
# %matplotlib inline

ax = red_pca_df.plot(kind='scatter', x='CP_1', y='CP_2', figsize=(16,8))

for i, pais in enumerate(red_pca_df.index):
    ax.annotate(pais, (red_pca_df.iloc[i].CP_1, red_pca_df.iloc[i].CP_2))

# %% [markdown]
# En general, cada vez que realicé un muestreo diferente, la primer componente principal explica la mayor parte de la variación, y por lo tanto la distribución de los paises a lo largo del eje `CP_1` explica mejor las diferencias entre paises.

# %% [markdown]
# ## Buscando similitudes entre paises usando las K-medias

# %% [markdown]
# Con el fin de encontrar un posible regrupamiento de los paises en casos representativos, vamos a utilizar el método de las K-medias. Un problema grande del uso del algoritmo de las K-medias es determinar el número correcto del regrupamientos, problema que en general hay que resolver a pulmón.
#
# Para esto, vamos a utilizar una técnica semi automátixzada llamada *el método del codo*, en la cuálse calcula las k-medias para K=2, 3, .., maxK, y luego se mide el costo de la solución con este número de clusters. Se espera que tiendan a 0 conforme K tiende al número de objetos, pero nos vamos a fijar en donde se encuentran algún punto de quiebre en la gráfica que nos indique que ese número de algomeraciones es correcto. Por supuesto es solo un criterio semiformal y el criterio subjetivo juega un papel importante.
#
# El número máximo de clusters se determina por la aplicación que vamos a realizar. Por ejemplo, en este caso que queremos analisar 30 paises, más de 5 agrupaciones diferentes sería demasiado.

# %%
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt

maxK = 6
listaK = range(2,maxK + 1)
costos=[]

for k in listaK:
    kmeans = KMeans(n_clusters=k)
    kmeans.fit(red_df)
    costos.append(-kmeans.score(red_df))
    
plt.figure(figsize=(16,8))
plt.plot(listaK, costos, '-or')
plt.xlabel('Número de clusters')
plt.ylabel('Costo')
plt.title('Selección de K con el método del codo')
# Out:
# Text(0.5,1,'Selección de K con el método del codo')

# %% [markdown]
# En el caso particular que yo tome (cada caso al repetirse es diferente) me encuentro con dos codos, uno en 3 y unos en 4, pero el de 4 es mñas pronunciado, así que me quedo con ese.
#
# #### Pregunta para contestar: ¿Cual fué el codo más pronunciado para tu caso particular? El segundo punto

# %% [markdown]
# Ahora agregamos los clusters obtenidos a los datos que ya habíamos reducido con PCA (par poder visualizarlos) y los graficamos de la misma manera.

# %%
K = 4
kmeans = KMeans(n_clusters=K)
clusters = kmeans.fit(red_df)
red_pca_df['grupos'] = pd.Series(clusters.labels_, index=red_pca_df.index)


ax = red_pca_df.plot(kind='scatter', x='CP_1', y='CP_2', 
                     c=red_pca_df.grupos.astype(float),
                     figsize=(16,8), s=300)

for i, pais in enumerate(red_pca_df.index):
    ax.annotate(pais, (red_pca_df.iloc[i].CP_1, red_pca_df.iloc[i].CP_2))

# %% [markdown]
# Muy bien. Ya tenemos un primer análisis. Sin embargo no tenemos una idea clara de que significan los clusters. Para eso vamos a analizar los prototipos de clases que tenemos, y los cuales están asociados con un conjunto de paises.

# %%
prototipos_df = pd.DataFrame(kmeans.cluster_centers_)
prototipos_df.index = ['P'+str(i + 1) for i in range(K)]
prototipos_df.columns = red_df.columns
prototipos_df.index.names = ['Protopipo']
prototipos_df.columns.names = ['Año']

prototipos_df
# Out:
# Año        Acceso a servicios de salud  Hogares con acceso a banda ancha  \
# Protopipo
# P1                           86.000000                         37.354286
# P2                           85.566667                         26.230000
# P3                           82.300000                         43.185000
# P4                           85.288889                         36.067778
#
# Año        Viviendas con acceso a servicios básicos  \
# Protopipo
# P1                                        90.700000
# P2                                        84.616667
# P3                                        95.300000
# P4                                        90.322222
#
# Año        Participación cívica y política  Participación electoral  \
# Protopipo
# P1                                6.457143                50.971429
# P2                                8.333333                49.116667
# P3                                3.350000                47.350000
# P4                                7.133333                49.422222
#
# Año        Confianza en la aplicación de la ley  \
# Protopipo
# P1                                     6.178571
# P2                                     7.642500
# P3                                     1.415000
# P4                                     5.223333
#
# Año        Percepción de ausencia de corrupción en el sistema judicial  \
# Protopipo
# P1                                                 35.285714
# P2                                                 33.900000
# P3                                                 20.500000
# P4                                                 28.900000
#
# Año        Percepción de confianza en los jueces  \
# Protopipo
# P1                                     60.842857
# P2                                     62.466667
# P3                                     39.650000
# P4                                     57.244444
#
# Año        Calidad de la red social de soporte  Esperanza de vida al nacer  \
# Protopipo
# P1                                   80.642857                   75.842857
# P2                                   77.375000                   74.875000
# P3                                   72.150000                   75.800000
# P4                                   78.966667                   75.333333
#
# Año                                    ...                               \
# Protopipo                              ...
# P1                                     ...
# P2                                     ...
# P3                                     ...
# P4                                     ...
#
# Año        Porcentaje de la población en situación de pobreza  \
# Protopipo
# P1                                                 34.428571
# P2                                                 49.691667
# P3                                                 37.750000
# P4                                                 38.633333
#
# Año        Porcentaje de la población en situación de pobreza extrema  \
# Protopipo
# P1                                                  4.300000
# P2                                                 10.541667
# P3                                                  3.950000
# P4                                                  6.066667
#
# Año        Tasa de condiciones críticas de ocupación  \
# Protopipo
# P1                                         11.314286
# P2                                         16.583333
# P3                                         13.650000
# P4                                         11.266667
#
# Año        Tasa de informalidad laboral  Tasa de desocupación  \
# Protopipo
# P1                            51.170000              4.614286
# P2                            65.388333              3.141667
# P3                            52.360000              5.100000
# P4                            54.436667              3.655556
#
# Año        Tasa de participación económica  Contaminación del aire  \
# Protopipo
# P1                               62.357143                9.042857
# P2                               59.233333                8.325000
# P3                               60.300000               15.400000
# P4                               60.122222               12.466667
#
# Año        Disposición de residuos  Habitaciones por persona  \
# Protopipo
# P1                       70.671429                  1.000000
# P2                       46.416667                  0.908333
# P3                       78.750000                  1.100000
# P4                       65.344444                  0.933333
#
# Año        Porcentaje de viviendas con techos de materiales resistentes
# Protopipo
# P1                                                 69.714286
# P2                                                 65.975000
# P3                                                 86.650000
# P4                                                 77.133333
#
# [4 rows x 37 columns]

# %% [markdown]
# Lo que es más fácil de analizar que 30 paises. Inclusive se pueden graficar en el tiempo y tiene sentido.

# %%
prototipos_df.T.plot(figsize=(16,8))

# %% [markdown]
# #### Pregunta para contestar: En función de las gráficas, da una explicación coherente a los diferentes prototipos y que puede significar (i.e. paises con mucha tuberculosis que van mejorando, paises que van empeorando en cuanto a casos de tuberculosis, paises que experimentaron un pico el año XXXX, etc...)
# No se puede graficar bien porque en la tabla 'indicadores_bienestar_2014.csv' no da informacion sobre el tiempo.
